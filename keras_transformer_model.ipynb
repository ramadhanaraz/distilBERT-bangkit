# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanaraz/distilBERT-bangkit/blob/main/keras_transformer_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 45.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import nltk
import pickle
import matplotlib.pyplot as plt
import itertools
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, Input
from nltk.corpus import stopwords
from tqdm import tqdm
from transformers import BertTokenizer, TFBertModel, BertConfig,TFDistilBertModel,DistilBertTokenizer,DistilBertConfig

# %%
## DistilBERT load
dbert_tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
dbert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpp13roz4i
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# storing https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# creating metadata file for /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpq2iog_du
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# ...

# %%
def dBERT_model(num_classes, max_len):
    input = Input(shape = (max_len,), dtype='int64')
    mask = Input(shape = (max_len,), dtype='int64')
    dbert_layer = dbert_model(input, attention_mask=mask)[0][:,0,:]
    dense1 = Dense(256, activation='relu')(dbert_layer)
    dropout= Dropout(0.4)(dense1)
    denselast = Dense(num_classes, activation='softmax')(dropout)
    model = tf.keras.Model(inputs=[input, mask], outputs=denselast)
    print(model.summary())
    return model

# %%
def toEmbedding(sentences, max_len, labels):  
  input_ids=[]
  attention_masks=[]

  for sentence in sentences:
      dbert_inputs = dbert_tokenizer.encode_plus(sentence, 
                                               add_special_tokens = True, 
                                               max_length = max_len, 
                                               pad_to_max_length = True, 
                                               return_attention_mask = True, 
                                               truncation = True)
      input_ids.append(dbert_inputs['input_ids'])
      attention_masks.append(dbert_inputs['attention_mask'])

  input_ids = np.asarray(input_ids)
  attention_masks = np.array(attention_masks)
  labels = np.array(labels)

  return input_ids, attention_masks, labels

# %%
def toPickle(input_ids, attention_masks, labels, path):
  pickle_input_path = os.join(path, "dbert_inputs.pkl")
  pickle_mask_path = os.join(path, "dbert_masks.pkl")
  pickle_label_path = os.join(path, "dbert_labels.pkl")

  pickle.dump((input_ids), open(pickle_input_path,'wb'))
  pickle.dump((attention_masks), open(pickle_mask_path,'wb'))
  pickle.dump((labels), open(pickle_label_path,'wb'))

  print('Saving in ', pickle_inp_path, pickle_mask_path, pickle_label_path)

# %%
def fromPickle(input_path, mask_path, label_path):
  input_ids = pickle.load(open(input_path, 'rb'))
  attention_masks = pickle.load(open(mask_path, 'rb'))
  labels = pickle.load(open(label_path, 'rb'))

  print('Input shape {} Attention mask shape {} Input label shape {}'.format(input_ids.shape,attention_masks.shape,labels.shape))
  return input_ids, attention_masks, labels

# %%
log_dir='dbert_model'
model_save_path='./dbert_model.h5'

num_classes = 132
max_len = 762

loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)

model = dBERT_model(num_classes, max_len)

model.compile(loss=loss,optimizer=optimizer, metrics=[metric])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 762)]        0           []
#
#  input_2 (InputLayer)           [(None, 762)]        0           []
#
#  tf_distil_bert_model (TFDistil  TFBaseModelOutput(l  66362880   ['input_1[0][0]',
#  BertModel)                     ast_hidden_state=(N               'input_2[0][0]']
#                                 one, 762, 768),
#                                  hidden_states=None
#                                 , attentions=None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['tf_distil_bert_model[0][0]']
#  ingOpLambda)
#
#  dense (Dense)                  (None, 256)          196864      ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
# ...
